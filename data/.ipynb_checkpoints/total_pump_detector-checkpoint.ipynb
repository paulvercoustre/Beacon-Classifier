# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ad-hoc functions ###

# %%
#choose a proba threshold below which the model outputs 'unknown class'
def acc_threshold(proba, X, y):
    for i in np.linspace(start=0.7, stop=0.99, num=21):
        idx = np.where(np.max(proba, axis=1) > i)[0] # samples where model is confident enough given threshold
        n_classif_samples = idx.shape[0]

        #compute accuracy
        accuracy = model.score(X[idx], y[idx])
        print("With: %.3f, %g samples (%.3f of samples) classified with accuracy: %.3f" % 
          (i, n_classif_samples, n_classif_samples/y.shape[0], accuracy))

# %%
#displays accuracy per pump
def acc_pump(model, X, y):
    n_pump = int(max(y))
    accuracy = np.zeros(n_pump)
    for pump in range(n_pump):
        #get the labels id where label = pump
        idx = np.where(y == pump + 1)
    
        #compute accuracy
        accuracy[pump] = model.score(X[idx], y[idx])
        print("The accuracy of pump %g is: %.3f" % ((pump + 1), accuracy[pump]))
        
    plt.bar(range(1,9), height=accuracy)
    plt.show()

# %% [markdown]
# ### Import and plot the data ###

# %%
# import the data
data = np.genfromtxt('no_filter.csv', delimiter=",", skip_header=1, usecols=range(1, 24), filling_values=-120)
print(data.shape)
# Out:
# (4123, 23)

# %%
#create features and labels
X = data[:,2:24]  # each feature is the signal intensity of a given beacon at a given timestep
y = data[:,0]

n_samples, n_features = X.shape

# %%
print(y)
print(X)
# Out:
# [ 2.  4.  3. ...,  7.  7.  7.]
# [[ -89.  -87.  -88. ..., -120. -120. -120.]
#  [-120. -120. -120. ..., -120. -120. -120.]
#  [-120. -120. -120. ..., -120. -120. -120.]
#  ...,
#  [ -93.  -90.  -90. ...,  -91.  -86.  -82.]
#  [ -91.  -91.  -92. ...,  -88.  -88.  -85.]
#  [ -91.  -89.  -92. ...,  -89.  -89.  -91.]]

# %%
#plot the labels to see class balance
plt.hist(y, 8)
plt.xlabel("Pump")
plt.ylabel("Number of tests")
plt.title("Nb of tests per pump")
plt.show()

# %%
#plot the features distribution
for i in range(X.shape[1]):
    plt.hist(X[:,i], 20)
    plt.show()

# %%
#split the data for training and testing

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

n_test_samples = y_test.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fdb54bde61c2> in <module>()
#       2
#       3 from sklearn.model_selection import train_test_split
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#       5
#       6 n_test_samples = y_test.shape[0]
#
# NameError: name 'X' is not defined

# %%
#take the log and standardise the data
from sklearn import preprocessing

X_train = np.log(np.abs(X_train))

scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

X_test = np.log(np.abs(X_test))
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dfb8345662d8> in <module>()
#       2 from sklearn import preprocessing
#       3
# ----> 4 X_train = np.log(np.abs(X_train))
#       5
#       6 scaler = preprocessing.StandardScaler().fit(X_train)
#
# NameError: name 'np' is not defined

# %%
#plot the features distribution
for i in range(X_train.shape[1]):
    plt.hist(X_test[:,i], 20)
    plt.show()

# %% [markdown]
# ### Train a simple linear model: logistic regression ###

# %%
#train a multinomial classification
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(multi_class='multinomial', solver='lbfgs').fit(X_train, y_train)

print("training score : %.3f (%s)" % (model.score(X_train, y_train), 'multinomial'))

#evaluate model on test set
print("testing score : %.3f (%s)" % (model.score(X_test, y_test), 'multinomial'))

predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d301e51ed4fb> in <module>()
#       2 from sklearn.linear_model import LogisticRegression
#       3
# ----> 4 model = LogisticRegression(multi_class='multinomial', solver='lbfgs').fit(X_train, y_train)
#       5
#       6 print("training score : %.3f (%s)" % (model.score(X_train, y_train), 'multinomial'))
#
# NameError: name 'X_train' is not defined

# %%
proba = model.predict_proba(X_test)
acc_threshold(proba, X=X_test, y=y_test)
# Out:
# With: 0.700, 751 samples (0.910 of samples) classified with accuracy: 0.960
# With: 0.714, 751 samples (0.910 of samples) classified with accuracy: 0.960
# With: 0.729, 745 samples (0.903 of samples) classified with accuracy: 0.960
# With: 0.743, 737 samples (0.893 of samples) classified with accuracy: 0.963
# With: 0.758, 728 samples (0.882 of samples) classified with accuracy: 0.963
# With: 0.772, 718 samples (0.870 of samples) classified with accuracy: 0.962
# With: 0.787, 716 samples (0.868 of samples) classified with accuracy: 0.962
# With: 0.801, 706 samples (0.856 of samples) classified with accuracy: 0.963
# With: 0.816, 695 samples (0.842 of samples) classified with accuracy: 0.967
# With: 0.831, 682 samples (0.827 of samples) classified with accuracy: 0.966
# With: 0.845, 670 samples (0.812 of samples) classified with accuracy: 0.967
# With: 0.859, 657 samples (0.796 of samples) classified with accuracy: 0.968
# With: 0.874, 646 samples (0.783 of samples) classified with accuracy: 0.969
# With: 0.888, 629 samples (0.762 of samples) classified with accuracy: 0.968
# With: 0.903, 611 samples (0.741 of samples) classified with accuracy: 0.967
# With: 0.917, 590 samples (0.715 of samples) classified with accuracy: 0.971
# With: 0.932, 572 samples (0.693 of samples) classified with accuracy: 0.972
# With: 0.947, 535 samples (0.648 of samples) classified with accuracy: 0.974
# With: 0.961, 488 samples (0.592 of samples) classified with accuracy: 0.973
# With: 0.976, 407 samples (0.493 of samples) classified with accuracy: 0.975
# With: 0.990, 283 samples (0.343 of samples) classified with accuracy: 0.979

# %%
acc_pump(model=model, X=X_test, y=y_test)
# Out:
# The accuracy of pump 1 is: 0.964
# The accuracy of pump 2 is: 0.941
# The accuracy of pump 3 is: 0.988
# The accuracy of pump 4 is: 0.958
# The accuracy of pump 5 is: 0.892
# The accuracy of pump 6 is: 0.985
# The accuracy of pump 7 is: 0.863
# The accuracy of pump 8 is: 0.882

# %% [markdown]
# ### Train a cross validated SVM ###

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
n_test_samples = y_test.shape[0]

#take the log value of the absolute value of features
X_train = np.log(np.abs(X_train))
X_test = np.log(np.abs(X_test))

estimator = [('scaler', preprocessing.StandardScaler()), ('clf', SVC(probability = True))]
pipe = Pipeline(estimator)

param_grid = {'clf__C': [1], 'clf__gamma': [0.1], 'clf__kernel': ['rbf']}

model = GridSearchCV(pipe, param_grid=param_grid, cv=10, scoring='accuracy', verbose=1)
model.fit(X_train, y_train) 

pred_svm = model.predict(X_test)

print(model.best_params_)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   10.3s finished
# {'clf__C': 1, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}

# %%
print("training score : %.4f" % (model.score(X_train, y_train)))
print("testing score : %.4f" % (model.score(X_test, y_test)))
# Out:
# training score : 0.9651
# testing score : 0.9479

# %%
proba_svm = model.predict_proba(X_test)

acc_threshol(proba_svm, X=X_test, y=y_test)
# Out:
# With: 0.700, 772 samples (0.936 of samples) classified with accuracy: 0.970
# With: 0.714, 771 samples (0.935 of samples) classified with accuracy: 0.970
# With: 0.729, 768 samples (0.931 of samples) classified with accuracy: 0.973
# With: 0.743, 767 samples (0.930 of samples) classified with accuracy: 0.973
# With: 0.758, 763 samples (0.925 of samples) classified with accuracy: 0.974
# With: 0.772, 761 samples (0.922 of samples) classified with accuracy: 0.975
# With: 0.787, 758 samples (0.919 of samples) classified with accuracy: 0.975
# With: 0.801, 753 samples (0.913 of samples) classified with accuracy: 0.976
# With: 0.816, 750 samples (0.909 of samples) classified with accuracy: 0.977
# With: 0.831, 741 samples (0.898 of samples) classified with accuracy: 0.980
# With: 0.845, 730 samples (0.885 of samples) classified with accuracy: 0.979
# With: 0.859, 722 samples (0.875 of samples) classified with accuracy: 0.979
# With: 0.874, 712 samples (0.863 of samples) classified with accuracy: 0.979
# With: 0.888, 698 samples (0.846 of samples) classified with accuracy: 0.984
# With: 0.903, 681 samples (0.825 of samples) classified with accuracy: 0.987
# With: 0.917, 666 samples (0.807 of samples) classified with accuracy: 0.986
# With: 0.932, 651 samples (0.789 of samples) classified with accuracy: 0.986
# With: 0.947, 618 samples (0.749 of samples) classified with accuracy: 0.990
# With: 0.961, 567 samples (0.687 of samples) classified with accuracy: 0.991
# With: 0.976, 483 samples (0.585 of samples) classified with accuracy: 0.992
# With: 0.990, 297 samples (0.360 of samples) classified with accuracy: 0.993

# %%
acc_pump(model=model, X=X_test, y=y_test)
# Out:
# The accuracy of pump 1 is: 0.952
# The accuracy of pump 2 is: 0.966
# The accuracy of pump 3 is: 0.975
# The accuracy of pump 4 is: 0.979
# The accuracy of pump 5 is: 0.931
# The accuracy of pump 6 is: 0.985
# The accuracy of pump 7 is: 0.889
# The accuracy of pump 8 is: 0.903

# %% [markdown]
# ### Train a cross validated NN ###

# %%
from sklearn.neural_network import MLPClassifier

#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
n_test_samples = y_test.shape[0]

#take the log value of the absolute value of features
X_train = np.log(np.abs(X_train))
X_test = np.log(np.abs(X_test))

estimator = [('scaler', preprocessing.StandardScaler()), ('clf', MLPClassifier(max_iter=200))]
pipe = Pipeline(estimator)

param_grid = {'clf__solver': ['lbfgs'], 'clf__alpha': [1e-5], 
              'clf__hidden_layer_sizes': [3, 4, 5, [5, 5], [10, 10], [5, 10, 5]]}

nn_model = GridSearchCV(pipe, param_grid=param_grid, cv=10, scoring='accuracy', verbose=1)
nn_model.fit(X_train, y_train) 
    
pred_nn = nn_model.predict(X_test)

print(nn_model.best_params_)

print("training score : %.4f" % (model2.score(X_train, y_train)))
print("testing score : %.4f" % (model2.score(X_test, y_test)))
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   38.5s finished
# {'clf__alpha': 1e-05, 'clf__hidden_layer_sizes': 5, 'clf__solver': 'lbfgs'}
# training score : 0.9530
# testing score : 0.9309

# %%
proba_nn = nn_model.predict_proba(X_test)

acc_threshol(proba_nn, X=X_test, y=y_test)
# Out:
# With: 0.700, 769 samples (0.932 of samples) classified with accuracy: 0.958
# With: 0.714, 768 samples (0.931 of samples) classified with accuracy: 0.960
# With: 0.729, 767 samples (0.930 of samples) classified with accuracy: 0.960
# With: 0.743, 763 samples (0.925 of samples) classified with accuracy: 0.959
# With: 0.758, 760 samples (0.921 of samples) classified with accuracy: 0.959
# With: 0.772, 754 samples (0.914 of samples) classified with accuracy: 0.959
# With: 0.787, 751 samples (0.910 of samples) classified with accuracy: 0.959
# With: 0.801, 743 samples (0.901 of samples) classified with accuracy: 0.960
# With: 0.816, 736 samples (0.892 of samples) classified with accuracy: 0.962
# With: 0.831, 727 samples (0.881 of samples) classified with accuracy: 0.961
# With: 0.845, 719 samples (0.872 of samples) classified with accuracy: 0.961
# With: 0.859, 711 samples (0.862 of samples) classified with accuracy: 0.961
# With: 0.874, 704 samples (0.853 of samples) classified with accuracy: 0.962
# With: 0.888, 698 samples (0.846 of samples) classified with accuracy: 0.961
# With: 0.903, 682 samples (0.827 of samples) classified with accuracy: 0.962
# With: 0.917, 661 samples (0.801 of samples) classified with accuracy: 0.962
# With: 0.932, 641 samples (0.777 of samples) classified with accuracy: 0.966
# With: 0.947, 622 samples (0.754 of samples) classified with accuracy: 0.966
# With: 0.961, 598 samples (0.725 of samples) classified with accuracy: 0.968
# With: 0.976, 556 samples (0.674 of samples) classified with accuracy: 0.971
# With: 0.990, 399 samples (0.484 of samples) classified with accuracy: 0.972

# %%
acc_pump(model=nn_model, X=X_test, y=y_test)
# Out:
# The accuracy of pump 1 is: 0.952
# The accuracy of pump 2 is: 0.908
# The accuracy of pump 3 is: 0.926
# The accuracy of pump 4 is: 0.947
# The accuracy of pump 5 is: 0.922
# The accuracy of pump 6 is: 0.985
# The accuracy of pump 7 is: 0.838
# The accuracy of pump 8 is: 0.892

# %% [markdown]
# ### Model Averaging ###

# %%
#find samples similarly classified by both models
idx1 = np.where(pred_svm == pred_nn)

global_correct = sum(y_test[idx1] == pred_svm[idx1])
global_accuracy = global_correct/idx1[0].shape

print("Testing accuracy: %.3f" % global_accuracy)
print("%.3f testing samples classified" % (idx1[0].shape[0] / n_test_samples))
# Out:
# Testing accuracy: 0.958
# 0.954 testing samples classified

# %%
n_pump = int(max(y_test))
accuracy = np.zeros(n_pump)
for pump in range(n_pump):
    #get the labels id where label = pump
    idx = np.where(y_test[idx1] == pump + 1)
    
    #compute accuracy
    accuracy[pump] = sum(pred_svm[idx] == y_test[idx])/idx[0].shape
    print("The accuracy of pump %g is: %.3f" % ((pump + 1), accuracy[pump]))
        
plt.bar(range(1,9), height=accuracy)
plt.show()
# Out:
# The accuracy of pump 1 is: 0.988
# The accuracy of pump 2 is: 0.955
# The accuracy of pump 3 is: 0.933
# The accuracy of pump 4 is: 0.946
# The accuracy of pump 5 is: 0.928
# The accuracy of pump 6 is: 0.940
# The accuracy of pump 7 is: 0.952
# The accuracy of pump 8 is: 0.943

# %%
#choose a proba threshold below which the model outputs 'unknown class'
for i in np.linspace(start=0.7, stop=0.99, num=21):
    id_svm = np.where(np.max(proba_svm, axis=1) > i)[0]
    id_nn = np.where(np.max(proba_nn, axis=1) > i)[0]
    idx2 = list(set(id_svm).intersection(id_nn))
    idx = list(set(idx1[0]).intersection(idx2))
    n_classif_samples = len(idx)
    
    correct = sum(y_test[idx] == pred_svm[idx])
    accuracy = correct/n_classif_samples
    
    print("With: %.3f, %g samples (%.3f of samples) classified with accuracy: %.3f" % 
          (i, n_classif_samples, n_classif_samples/y_test.shape[0], accuracy))
# Out:
# With: 0.700, 730 samples (0.885 of samples) classified with accuracy: 0.973
# With: 0.714, 730 samples (0.885 of samples) classified with accuracy: 0.973
# With: 0.729, 728 samples (0.882 of samples) classified with accuracy: 0.974
# With: 0.743, 726 samples (0.880 of samples) classified with accuracy: 0.974
# With: 0.758, 719 samples (0.872 of samples) classified with accuracy: 0.975
# With: 0.772, 713 samples (0.864 of samples) classified with accuracy: 0.976
# With: 0.787, 709 samples (0.859 of samples) classified with accuracy: 0.976
# With: 0.801, 702 samples (0.851 of samples) classified with accuracy: 0.979
# With: 0.816, 696 samples (0.844 of samples) classified with accuracy: 0.980
# With: 0.831, 684 samples (0.829 of samples) classified with accuracy: 0.982
# With: 0.845, 674 samples (0.817 of samples) classified with accuracy: 0.982
# With: 0.859, 661 samples (0.801 of samples) classified with accuracy: 0.982
# With: 0.874, 652 samples (0.790 of samples) classified with accuracy: 0.982
# With: 0.888, 641 samples (0.777 of samples) classified with accuracy: 0.984
# With: 0.903, 622 samples (0.754 of samples) classified with accuracy: 0.987
# With: 0.917, 597 samples (0.724 of samples) classified with accuracy: 0.987
# With: 0.932, 576 samples (0.698 of samples) classified with accuracy: 0.988
# With: 0.947, 547 samples (0.663 of samples) classified with accuracy: 0.991
# With: 0.961, 507 samples (0.615 of samples) classified with accuracy: 0.990
# With: 0.976, 435 samples (0.527 of samples) classified with accuracy: 0.991
# With: 0.990, 219 samples (0.265 of samples) classified with accuracy: 0.995
